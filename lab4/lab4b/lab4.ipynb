# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
headers = ['Tree size', 'Search iterations']
data = pd.read_csv('profile.csv', names=headers)

# %%
data.set_index('Tree size').plot()
plt.show()
